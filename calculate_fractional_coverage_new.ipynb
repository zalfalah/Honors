# %%
import sys
if sys.platform == "darwin":  # michael's config
    # because Michael is using jupyter lab
    # %load_ext lab_black
else:  # zade's config
    # because Zade is using jupyter notebook
    # %load_ext nb_black

# %% [markdown]
# ## Tasks
#
# I have put several more utility functions into the coverage_utils module, have a look at all of them to understand what they do.
#
# Update: I added the CoverageCalculator, making things much easier...
# Update2: Initial investigations of results renders it necessary to create below new database for all three cases of fans, blotches and both areas considered in the union. I added a switch in the class that enables that kind of analysis. See below..
# Next tasks are:
#
# * [x] combine below code into a function with the name `calc_coverage(region_name)` that returns the pandas dataframe with the results (basically combining below cells into a function) but add a region_name column (same for all rows), in preparation for next task.
# * [x] run a loop over all available region names (see below for how to get that list).
#     * [ ] store each returned dataframe in a bucket list
#     - Did the above inefficiently, still works (no bucket list)
#     * [x] run each obsid three times, for `which` settings of 'both', 'fans' and 'blotches'
#     * [x] combine the bucket into a larger dataframe that has all results
#     * [x] save as CSV file using df.to_csv(...)
# * [ ] Develep a plot function with the cells below, that conveniently reads the data out the above stored large dataframe and creates the plot, using the options as below.

# %% [markdown]
# # CoverageCalculator class
#
# I wrote a class because it's much more efficient to keep the fans, blotches and metadata in memory and not read it in everytime.
# Keep that in mind for the future: When you need to read a data object often, it is more efficient to write a class that keeps that data in memory while you change a parameter (here: obsid) for different analyses.
#
# This class reads in the general data files once and you can then use it in a loop by setting the obsid value as shown below.

# %%
import pandas as pd
import numpy as np
import geopandas as gp
import shapely
from planet4 import io, markings

# %%
from coverage_utils import CoverageCalculator, get_obsids_for_region
from my_io import get_tilecoords, get_metadata, get_region_names

# %%
# must keep for next line cc = Coverage.. to work
obsid = "ESP_011341_0980"

# %%
# the `which` setting is by default 'both'
cc = CoverageCalculator()
# Out:
# Reading fans and blotches in...
# Done.
# Reading metadata...
# Done.
# Note that obsid must be set to a string value before this works.

# %%
all_regions = get_region_names().roi_name.unique()

# %%
all_regions = [
    region for region in all_regions if region not in ["unknown", "Manhattan2"]
]

# %%
all_regions
# Out:
# ['Macclesfield',
#  'Starburst',
#  'Manhattan_Classic',
#  'Wellington',
#  'Albany',
#  'Bilbao',
#  'Ithaca',
#  'Portsmouth',
#  'Pisaq',
#  'Manhattan_Frontinella',
#  'BuenosAires',
#  'Inca_City_Ridges',
#  'Inca_City',
#  'Giza',
#  'Potsdam',
#  'Troy',
#  'Oswego_Edge',
#  'Halifax',
#  'Caterpillar',
#  'Rochester',
#  'Manhattan_Cracks',
#  'Schenectady',
#  'Binghamton',
#  'Atka',
#  'Cortland',
#  'Geneseo']

# %%
def coverage_calc(given_region):
    bucket = []
    for MY in [29, 30]:
        print(f"Martian year: {MY}")
        for which in ["both", "fans", "blotches"]:
            cc.which = which
            for obsid in get_obsids_for_region(given_region, MY):
                print(f"Calculating obsid {obsid}")
                d = {}
                d["obsid"] = obsid
                cc.obsid = obsid
                try:
                    d["n_objects"] = len(cc.union)
                except TypeError:
                    if isinstance(cc.union, shapely.geometry.Polygon):
                        d["n_objects"] = 1
                    else:
                        d["n_objects"] = np.nan
                d["pixel_area"] = cc.union.area
                d["MY"] = MY
                d["fraction"] = cc.covered_fraction
                d["Ls"] = cc.Ls
                d["Which"] = which
                d["Latitude"] = cc.Lat
                d["region_name"] = given_region
                bucket.append(d)
    results = pd.DataFrame(bucket)
    return results

# %%
# OLD, USE ONLY AS REFERENCE!
def calc_coverage(given_region, which="both"):
    bucket = []
    roi = given_region
    cc.which = which
    for MY in [29, 30]:
        print(f"Martian year: {MY}")
        for obsid in get_obsids_for_region(roi, MY):
            print(f"Calculating obsid {obsid}")
            d = {}
            d["obsid"] = obsid
            d["MY"] = MY
            cc.obsid = obsid
            d["fraction"] = cc.covered_fraction
            d["Ls"] = cc.Ls
            bucket.append(d)
    results = pd.DataFrame(bucket)
    results["region_name"] = given_region
    results["which"] = which
    return results

# %%
# gives calc_coverage results for all regions, which = 'both'
calc_region = [coverage_calc(region) for region in all_regions]
# Out:
# Martian year: 29
# Calculating obsid ESP_012079_0945
# Calculating obsid ESP_011407_0945
# Calculating obsid ESP_011723_0945
# Calculating obsid ESP_011934_0945
# Calculating obsid ESP_012501_0945
# Calculating obsid ESP_012290_0945
# Calculating obsid ESP_011406_0945
# Calculating obsid ESP_012079_0945
# Calculating obsid ESP_011407_0945
# Calculating obsid ESP_011723_0945
# Calculating obsid ESP_011934_0945
# Calculating obsid ESP_012501_0945
# Calculating obsid ESP_012290_0945
# Calculating obsid ESP_011406_0945
# Calculating obsid ESP_012079_0945
# Calculating obsid ESP_011407_0945
# Calculating obsid ESP_011723_0945
# Calculating obsid ESP_011934_0945
# Calculating obsid ESP_012501_0945
# Calculating obsid ESP_012290_0945
# Calculating obsid ESP_011406_0945
# Martian year: 30
# Calculating obsid ESP_021494_0945
# Calculating obsid ESP_020782_0945
# Calculating obsid ESP_020716_0945
# Calculating obsid ESP_020571_0945
# Calculating obsid ESP_020294_0945
# Calculating obsid ESP_020927_0945
# Calculating obsid ESP_020242_0945
# Calculating obsid ESP_021494_0945
# Calculating obsid ESP_020782_0945
# Calculating obsid ESP_020716_0945
# Calculating obsid ESP_020571_0945
# Calculating obsid ESP_020294_0945
# Calculating obsid ESP_020927_0945
# Calculating obsid ESP_020242_0945
# Calculating obsid ESP_021494_0945
# Calculating obsid ESP_020782_0945
# Calculating obsid ESP_020716_0945
# Calculating obsid ESP_020571_0945
# Calculating obsid ESP_020294_0945
# Calculating obsid ESP_020927_0945
# Calculating obsid ESP_020242_0945
# Martian year: 29
# Calculating obsid ESP_011697_0980
# Calculating obsid ESP_011341_0980
# Calculating obsid ESP_011842_0980
# Calculating obsid ESP_011486_0980
# Calculating obsid ESP_012607_0980
# Calculating obsid ESP_012053_0980
# Calculating obsid ESP_012264_0980
# Calculating obsid ESP_011697_0980
# Calculating obsid ESP_011341_0980
# Calculating obsid ESP_011842_0980
# Calculating obsid ESP_011486_0980
# Calculating obsid ESP_012607_0980
# Calculating obsid ESP_012053_0980
# Calculating obsid ESP_012264_0980
# Calculating obsid ESP_011697_0980
# Calculating obsid ESP_011341_0980
# Calculating obsid ESP_011842_0980
# Calculating obsid ESP_011486_0980
# Calculating obsid ESP_012607_0980
# Calculating obsid ESP_012053_0980
# Calculating obsid ESP_012264_0980
# Martian year: 30
# Calculating obsid ESP_020677_0980
# Calculating obsid ESP_020756_0980
# Calculating obsid ESP_021969_0980
# Calculating obsid ESP_020677_0980
# Calculating obsid ESP_020756_0980
# Calculating obsid ESP_021969_0980
# Calculating obsid ESP_020677_0980
# Calculating obsid ESP_020756_0980
# Calculating obsid ESP_021969_0980
# Martian year: 29
# Calculating obsid ESP_012884_0935
# Calculating obsid ESP_012251_0935
# Calculating obsid ESP_012739_0935
# Calculating obsid ESP_011961_0935
# Calculating obsid ESP_011671_0935
# Calculating obsid ESP_013016_0935
# Calculating obsid ESP_011394_0935
# Calculating obsid ESP_013095_0935
# Calculating obsid ESP_012884_0935
# Calculating obsid ESP_012251_0935
# Calculating obsid ESP_012739_0935
# Calculating obsid ESP_011961_0935
# Calculating obsid ESP_011671_0935
# Calculating obsid ESP_013016_0935
# Calculating obsid ESP_011394_0935
# Calculating obsid ESP_013095_0935
# Calculating obsid ESP_012884_0935
# Calculating obsid ESP_012251_0935
# Calculating obsid ESP_012739_0935
# Calculating obsid ESP_011961_0935
# Calculating obsid ESP_011671_0935
# Calculating obsid ESP_013016_0935
# Calculating obsid ESP_011394_0935
# Calculating obsid ESP_013095_0935
# Martian year: 30
# Calculating obsid ESP_021455_0935
# Calculating obsid ESP_020519_0935
# Calculating obsid ESP_021495_0935
# Calculating obsid ESP_020954_0935
# Calculating obsid ESP_020598_0935
# Calculating obsid ESP_020214_0935
# Calculating obsid ESP_022260_0935
# Calculating obsid ESP_020321_0935
# Calculating obsid ESP_020202_0935
# Calculating obsid ESP_021455_0935
# Calculating obsid ESP_020519_0935
# Calculating obsid ESP_021495_0935
# Calculating obsid ESP_020954_0935
# Calculating obsid ESP_020598_0935
# Calculating obsid ESP_020214_0935
# Calculating obsid ESP_022260_0935
# Calculating obsid ESP_020321_0935
# Calculating obsid ESP_020202_0935
# Calculating obsid ESP_021455_0935
# Calculating obsid ESP_020519_0935
# Calculating obsid ESP_021495_0935
# Calculating obsid ESP_020954_0935
# Calculating obsid ESP_020598_0935
# Calculating obsid ESP_020214_0935
# Calculating obsid ESP_022260_0935
# Calculating obsid ESP_020321_0935
# Calculating obsid ESP_020202_0935
# Martian year: 29
# Calculating obsid ESP_012008_0975
# Calculating obsid ESP_011296_0975
# Calculating obsid ESP_012008_0975
# Calculating obsid ESP_011296_0975
# Calculating obsid ESP_012008_0975
# Calculating obsid ESP_011296_0975
# Martian year: 30
# Martian year: 29
# Calculating obsid ESP_012436_0980
# Calculating obsid ESP_012291_0980
# Calculating obsid ESP_012647_0980
# Calculating obsid ESP_012304_0980
# Calculating obsid ESP_012225_0980
# Calculating obsid ESP_012436_0980
# Calculating obsid ESP_012291_0980
# Calculating obsid ESP_012647_0980
# Calculating obsid ESP_012304_0980
# Calculating obsid ESP_012225_0980
# Calculating obsid ESP_012436_0980
# Calculating obsid ESP_012291_0980
# Calculating obsid ESP_012647_0980
# Calculating obsid ESP_012304_0980
# Calculating obsid ESP_012225_0980
# Martian year: 30
# Martian year: 29
# Calculating obsid ESP_011565_0930
# Calculating obsid ESP_012211_0930
# Calculating obsid ESP_011776_0930
# Calculating obsid ESP_012633_0930
# Calculating obsid ESP_012844_0930
# Calculating obsid ESP_012488_0930
# Calculating obsid ESP_011420_0930
# Calculating obsid ESP_011565_0930
# Calculating obsid ESP_012211_0930
# Calculating obsid ESP_011776_0930
# Calculating obsid ESP_012633_0930
# Calculating obsid ESP_012844_0930
# Calculating obsid ESP_012488_0930
# Calculating obsid ESP_011420_0930
# Calculating obsid ESP_011565_0930
# Calculating obsid ESP_012211_0930
# Calculating obsid ESP_011776_0930
# Calculating obsid ESP_012633_0930
# Calculating obsid ESP_012844_0930
# Calculating obsid ESP_012488_0930
# Calculating obsid ESP_011420_0930
# Martian year: 30
# Calculating obsid ESP_020347_0930
# Calculating obsid ESP_021903_0930
# Calculating obsid ESP_020558_0930
# Calculating obsid ESP_020347_0930
# Calculating obsid ESP_021903_0930
# Calculating obsid ESP_020558_0930
# Calculating obsid ESP_020347_0930
# Calculating obsid ESP_021903_0930
# Calculating obsid ESP_020558_0930
# Martian year: 29
# Calculating obsid ESP_011931_0945
# Calculating obsid ESP_012063_0945
# Calculating obsid ESP_011350_0945
# Calculating obsid ESP_012076_0945
# Calculating obsid ESP_012643_0945
# Calculating obsid ESP_012854_0945
# Calculating obsid ESP_011351_0945
# Calculating obsid ESP_011404_0945
# Calculating obsid ESP_011403_0945
# Calculating obsid ESP_012858_0855
# Calculating obsid ESP_011931_0945
# Calculating obsid ESP_012063_0945
# Calculating obsid ESP_011350_0945
# Calculating obsid ESP_012076_0945
# Calculating obsid ESP_012643_0945
# Calculating obsid ESP_012854_0945
# Calculating obsid ESP_011351_0945
# Calculating obsid ESP_011404_0945
# Calculating obsid ESP_011403_0945
# Calculating obsid ESP_012858_0855
# Calculating obsid ESP_011931_0945
# Calculating obsid ESP_012063_0945
# Calculating obsid ESP_011350_0945
# Calculating obsid ESP_012076_0945
# Calculating obsid ESP_012643_0945
# Calculating obsid ESP_012854_0945
# Calculating obsid ESP_011351_0945
# Calculating obsid ESP_011404_0945
# Calculating obsid ESP_011403_0945
# Calculating obsid ESP_012858_0855
# Martian year: 30
# Calculating obsid ESP_020357_0950
# Calculating obsid ESP_020476_0950
# Calculating obsid ESP_021491_0950
# Calculating obsid ESP_020779_0950
# Calculating obsid ESP_020146_0950
# Calculating obsid ESP_020568_0950
# Calculating obsid ESP_020357_0950
# Calculating obsid ESP_020476_0950
# Calculating obsid ESP_021491_0950
# Calculating obsid ESP_020779_0950
# Calculating obsid ESP_020146_0950
# Calculating obsid ESP_020568_0950
# Calculating obsid ESP_020357_0950
# Calculating obsid ESP_020476_0950
# Calculating obsid ESP_021491_0950
# Calculating obsid ESP_020779_0950
# Calculating obsid ESP_020146_0950
# Calculating obsid ESP_020568_0950
# Martian year: 29
# Calculating obsid ESP_011960_0925
# Calculating obsid ESP_012817_0925
# Calculating obsid ESP_012316_0925
# Calculating obsid ESP_012527_0925
# Calculating obsid ESP_012461_0925
# Calculating obsid ESP_011960_0925
# Calculating obsid ESP_012817_0925
# Calculating obsid ESP_012316_0925
# Calculating obsid ESP_012527_0925
# Calculating obsid ESP_012461_0925
# Calculating obsid ESP_011960_0925
# Calculating obsid ESP_012817_0925
# Calculating obsid ESP_012316_0925
# Calculating obsid ESP_012527_0925
# Calculating obsid ESP_012461_0925
# Martian year: 30
# Calculating obsid ESP_020742_0925
# Calculating obsid ESP_021454_0925
# Calculating obsid ESP_021520_0925
# Calculating obsid ESP_020597_0925
# Calculating obsid ESP_020953_0925
# Calculating obsid ESP_020386_0925
# Calculating obsid ESP_020742_0925
# Calculating obsid ESP_021454_0925
# Calculating obsid ESP_021520_0925
# Calculating obsid ESP_020597_0925
# Calculating obsid ESP_020953_0925
# Calculating obsid ESP_020386_0925
# Calculating obsid ESP_020742_0925
# Calculating obsid ESP_021454_0925
# Calculating obsid ESP_021520_0925
# Calculating obsid ESP_020597_0925
# Calculating obsid ESP_020953_0925
# Calculating obsid ESP_020386_0925
# Martian year: 29
# Calculating obsid ESP_012077_0930
# Calculating obsid ESP_012499_0930
# Calculating obsid ESP_011431_0930
# Calculating obsid ESP_012077_0930
# Calculating obsid ESP_012499_0930
# Calculating obsid ESP_011431_0930
# Calculating obsid ESP_012077_0930
# Calculating obsid ESP_012499_0930
# Calculating obsid ESP_011431_0930
# Martian year: 30
# Calculating obsid ESP_020780_0930
# Calculating obsid ESP_020780_0930
# Calculating obsid ESP_020780_0930
# Martian year: 29
# Calculating obsid ESP_011711_0930
# Calculating obsid ESP_012990_0930
# Calculating obsid ESP_012634_0930
# Calculating obsid ESP_011856_0930
# Calculating obsid ESP_012779_0930
# Calculating obsid ESP_011711_0930
# Calculating obsid ESP_012990_0930
# Calculating obsid ESP_012634_0930
# Calculating obsid ESP_011856_0930
# Calculating obsid ESP_012779_0930
# Calculating obsid ESP_011711_0930
# Calculating obsid ESP_012990_0930
# Calculating obsid ESP_012634_0930
# Calculating obsid ESP_011856_0930
# Calculating obsid ESP_012779_0930
# Martian year: 30
# Calculating obsid ESP_020176_0930
# Calculating obsid ESP_020427_0930
# Calculating obsid ESP_020282_0930
# Calculating obsid ESP_020176_0930
# Calculating obsid ESP_020427_0930
# Calculating obsid ESP_020282_0930
# Calculating obsid ESP_020176_0930
# Calculating obsid ESP_020427_0930
# Calculating obsid ESP_020282_0930
# Martian year: 29
# Calculating obsid ESP_012227_0980
# Calculating obsid ESP_012860_0980
# Calculating obsid ESP_012939_0980
# Calculating obsid ESP_011370_0980
# Calculating obsid ESP_012504_0980
# Calculating obsid ESP_011792_0980
# Calculating obsid ESP_011515_0980
# Calculating obsid ESP_012227_0980
# Calculating obsid ESP_012860_0980
# Calculating obsid ESP_012939_0980
# Calculating obsid ESP_011370_0980
# Calculating obsid ESP_012504_0980
# Calculating obsid ESP_011792_0980
# Calculating obsid ESP_011515_0980
# Calculating obsid ESP_012227_0980
# Calculating obsid ESP_012860_0980
# Calculating obsid ESP_012939_0980
# Calculating obsid ESP_011370_0980
# Calculating obsid ESP_012504_0980
# Calculating obsid ESP_011792_0980
# Calculating obsid ESP_011515_0980
# Martian year: 30
# Calculating obsid ESP_021642_0980
# Calculating obsid ESP_020376_0980
# Calculating obsid ESP_020297_0980
# Calculating obsid ESP_020719_0980
# Calculating obsid ESP_020508_0980
# Calculating obsid ESP_021497_0980
# Calculating obsid ESP_020930_0980
# Calculating obsid ESP_021642_0980
# Calculating obsid ESP_020376_0980
# Calculating obsid ESP_020297_0980
# Calculating obsid ESP_020719_0980
# Calculating obsid ESP_020508_0980
# Calculating obsid ESP_021497_0980
# Calculating obsid ESP_020930_0980
# Calculating obsid ESP_021642_0980
# Calculating obsid ESP_020376_0980
# Calculating obsid ESP_020297_0980
# Calculating obsid ESP_020719_0980
# Calculating obsid ESP_020508_0980
# Calculating obsid ESP_021497_0980
# Calculating obsid ESP_020930_0980
# Martian year: 29
# Calculating obsid ESP_011900_0985
# Calculating obsid ESP_012691_0985
# Calculating obsid ESP_012322_0985
# Calculating obsid ESP_011702_0985
# Calculating obsid ESP_011623_0985
# Calculating obsid ESP_012889_0985
# Calculating obsid ESP_011557_0985
# Calculating obsid ESP_011900_0985
# Calculating obsid ESP_012691_0985
# Calculating obsid ESP_012322_0985
# Calculating obsid ESP_011702_0985
# Calculating obsid ESP_011623_0985
# Calculating obsid ESP_012889_0985
# Calculating obsid ESP_011557_0985
# Calculating obsid ESP_011900_0985
# Calculating obsid ESP_012691_0985
# Calculating obsid ESP_012322_0985
# Calculating obsid ESP_011702_0985
# Calculating obsid ESP_011623_0985
# Calculating obsid ESP_012889_0985
# Calculating obsid ESP_011557_0985
# Martian year: 30
# Calculating obsid ESP_020339_0985
# Calculating obsid ESP_021526_0985
# Calculating obsid ESP_021605_0985
# Calculating obsid ESP_021671_0985
# Calculating obsid ESP_021684_0985
# Calculating obsid ESP_021829_0985
# Calculating obsid ESP_020827_0985
# Calculating obsid ESP_020115_0985
# Calculating obsid ESP_020339_0985
# Calculating obsid ESP_021526_0985
# Calculating obsid ESP_021605_0985
# Calculating obsid ESP_021671_0985
# Calculating obsid ESP_021684_0985
# Calculating obsid ESP_021829_0985
# Calculating obsid ESP_020827_0985
# Calculating obsid ESP_020115_0985
# Calculating obsid ESP_020339_0985
# Calculating obsid ESP_021526_0985
# Calculating obsid ESP_021605_0985
# Calculating obsid ESP_021671_0985
# Calculating obsid ESP_021684_0985
# Calculating obsid ESP_021829_0985
# Calculating obsid ESP_020827_0985
# Calculating obsid ESP_020115_0985
# Martian year: 29
# Calculating obsid ESP_012256_0985
# Calculating obsid ESP_012744_0985
# Calculating obsid ESP_011491_0985
# Calculating obsid ESP_012467_0985
# Calculating obsid ESP_013113_0985
# Calculating obsid ESP_011729_0985
# Calculating obsid ESP_013034_0985
# Calculating obsid ESP_011544_0985
# Calculating obsid ESP_012256_0985
# Calculating obsid ESP_012744_0985
# Calculating obsid ESP_011491_0985
# Calculating obsid ESP_012467_0985
# Calculating obsid ESP_013113_0985
# Calculating obsid ESP_011729_0985
# Calculating obsid ESP_013034_0985
# Calculating obsid ESP_011544_0985
# Calculating obsid ESP_012256_0985
# Calculating obsid ESP_012744_0985
# Calculating obsid ESP_011491_0985
# Calculating obsid ESP_012467_0985
# Calculating obsid ESP_013113_0985
# Calculating obsid ESP_011729_0985
# Calculating obsid ESP_013034_0985
# Calculating obsid ESP_011544_0985
# Martian year: 30
# Calculating obsid ESP_020748_0985
# Calculating obsid ESP_021460_0985
# Calculating obsid ESP_020959_0985
# Calculating obsid ESP_020128_0985
# Calculating obsid ESP_020049_0985
# Calculating obsid ESP_020194_0985
# Calculating obsid ESP_022699_0985
# Calculating obsid ESP_020748_0985
# Calculating obsid ESP_021460_0985
# Calculating obsid ESP_020959_0985
# Calculating obsid ESP_020128_0985
# Calculating obsid ESP_020049_0985
# Calculating obsid ESP_020194_0985
# Calculating obsid ESP_022699_0985
# Calculating obsid ESP_020748_0985
# Calculating obsid ESP_021460_0985
# Calculating obsid ESP_020959_0985
# Calculating obsid ESP_020128_0985
# Calculating obsid ESP_020049_0985
# Calculating obsid ESP_020194_0985
# Calculating obsid ESP_022699_0985
# Martian year: 29
# Calculating obsid ESP_012344_0950
# Calculating obsid ESP_011447_0950
# Calculating obsid ESP_012704_0850
# Calculating obsid ESP_011843_0950
# Calculating obsid ESP_012845_0950
# Calculating obsid ESP_012212_0950
# Calculating obsid ESP_012265_0950
# Calculating obsid ESP_011448_0950
# Calculating obsid ESP_012836_0850
# Calculating obsid ESP_011777_0950
# Calculating obsid ESP_012753_0950
# Calculating obsid ESP_012344_0950
# Calculating obsid ESP_011447_0950
# Calculating obsid ESP_012704_0850
# Calculating obsid ESP_011843_0950
# Calculating obsid ESP_012845_0950
# Calculating obsid ESP_012212_0950
# Calculating obsid ESP_012265_0950
# Calculating obsid ESP_011448_0950
# Calculating obsid ESP_012836_0850
# Calculating obsid ESP_011777_0950
# Calculating obsid ESP_012753_0950
# Calculating obsid ESP_012344_0950
# Calculating obsid ESP_011447_0950
# Calculating obsid ESP_012704_0850
# Calculating obsid ESP_011843_0950
# Calculating obsid ESP_012845_0950
# Calculating obsid ESP_012212_0950
# Calculating obsid ESP_012265_0950
# Calculating obsid ESP_011448_0950
# Calculating obsid ESP_012836_0850
# Calculating obsid ESP_011777_0950
# Calculating obsid ESP_012753_0950
# Martian year: 30
# Calculating obsid ESP_020783_0950
# Calculating obsid ESP_022273_0950
# Calculating obsid ESP_020401_0950
# Calculating obsid ESP_020150_0950
# Calculating obsid ESP_020902_0950
# Calculating obsid ESP_021482_0950
# Calculating obsid ESP_020480_0950
# Calculating obsid ESP_020783_0950
# Calculating obsid ESP_022273_0950
# Calculating obsid ESP_020401_0950
# Calculating obsid ESP_020150_0950
# Calculating obsid ESP_020902_0950
# Calculating obsid ESP_021482_0950
# Calculating obsid ESP_020480_0950
# Calculating obsid ESP_020783_0950
# Calculating obsid ESP_022273_0950
# Calculating obsid ESP_020401_0950
# Calculating obsid ESP_020150_0950
# Calculating obsid ESP_020902_0950
# Calculating obsid ESP_021482_0950
# Calculating obsid ESP_020480_0950
# Martian year: 29
# Calculating obsid ESP_011737_0980
# Calculating obsid ESP_012515_0980
# Calculating obsid ESP_011526_0980
# Calculating obsid ESP_012594_0980
# Calculating obsid ESP_012805_0980
# Calculating obsid ESP_011460_0980
# Calculating obsid ESP_012871_0980
# Calculating obsid ESP_011737_0980
# Calculating obsid ESP_012515_0980
# Calculating obsid ESP_011526_0980
# Calculating obsid ESP_012594_0980
# Calculating obsid ESP_012805_0980
# Calculating obsid ESP_011460_0980
# Calculating obsid ESP_012871_0980
# Calculating obsid ESP_011737_0980
# Calculating obsid ESP_012515_0980
# Calculating obsid ESP_011526_0980
# Calculating obsid ESP_012594_0980
# Calculating obsid ESP_012805_0980
# Calculating obsid ESP_011460_0980
# Calculating obsid ESP_012871_0980
# Martian year: 30
# Calculating obsid ESP_021587_0980
# Calculating obsid ESP_020374_0980
# Calculating obsid ESP_021521_0980
# Calculating obsid ESP_021508_0980
# Calculating obsid ESP_020875_0980
# Calculating obsid ESP_021574_0980
# Calculating obsid ESP_022510_0980
# Calculating obsid ESP_020163_0980
# Calculating obsid ESP_020941_0980
# Calculating obsid ESP_021587_0980
# Calculating obsid ESP_020374_0980
# Calculating obsid ESP_021521_0980
# Calculating obsid ESP_021508_0980
# Calculating obsid ESP_020875_0980
# Calculating obsid ESP_021574_0980
# Calculating obsid ESP_022510_0980
# Calculating obsid ESP_020163_0980
# Calculating obsid ESP_020941_0980
# Calculating obsid ESP_021587_0980
# Calculating obsid ESP_020374_0980
# Calculating obsid ESP_021521_0980
# Calculating obsid ESP_021508_0980
# Calculating obsid ESP_020875_0980
# Calculating obsid ESP_021574_0980
# Calculating obsid ESP_022510_0980
# Calculating obsid ESP_020163_0980
# Calculating obsid ESP_020941_0980
# Martian year: 29
# Calculating obsid ESP_012693_0950
# Calculating obsid ESP_012838_0950
# Calculating obsid ESP_013049_0950
# Calculating obsid ESP_011348_0950
# Calculating obsid ESP_013260_0950
# Calculating obsid ESP_012693_0950
# Calculating obsid ESP_012838_0950
# Calculating obsid ESP_013049_0950
# Calculating obsid ESP_011348_0950
# Calculating obsid ESP_013260_0950
# Calculating obsid ESP_012693_0950
# Calculating obsid ESP_012838_0950
# Calculating obsid ESP_013049_0950
# Calculating obsid ESP_011348_0950
# Calculating obsid ESP_013260_0950
# Martian year: 30
# Martian year: 29
# Calculating obsid ESP_012463_0930
# Calculating obsid ESP_013030_0930
# Calculating obsid ESP_011606_0930
# Calculating obsid ESP_012819_0930
# Calculating obsid ESP_012028_0930
# Calculating obsid ESP_011408_0930
# Calculating obsid ESP_012463_0930
# Calculating obsid ESP_013030_0930
# Calculating obsid ESP_011606_0930
# Calculating obsid ESP_012819_0930
# Calculating obsid ESP_012028_0930
# Calculating obsid ESP_011408_0930
# Calculating obsid ESP_012463_0930
# Calculating obsid ESP_013030_0930
# Calculating obsid ESP_011606_0930
# Calculating obsid ESP_012819_0930
# Calculating obsid ESP_012028_0930
# Calculating obsid ESP_011408_0930
# Martian year: 30
# Calculating obsid ESP_020322_0930
# Calculating obsid ESP_021522_0930
# Calculating obsid ESP_020678_0930
# Calculating obsid ESP_020955_0930
# Calculating obsid ESP_021654_0930
# Calculating obsid ESP_022379_0930
# Calculating obsid ESP_020731_0930
# Calculating obsid ESP_020533_0930
# Calculating obsid ESP_021483_0930
# Calculating obsid ESP_020229_0930
# Calculating obsid ESP_020322_0930
# Calculating obsid ESP_021522_0930
# Calculating obsid ESP_020678_0930
# Calculating obsid ESP_020955_0930
# Calculating obsid ESP_021654_0930
# Calculating obsid ESP_022379_0930
# Calculating obsid ESP_020731_0930
# Calculating obsid ESP_020533_0930
# Calculating obsid ESP_021483_0930
# Calculating obsid ESP_020229_0930
# Calculating obsid ESP_020322_0930
# Calculating obsid ESP_021522_0930
# Calculating obsid ESP_020678_0930
# Calculating obsid ESP_020955_0930
# Calculating obsid ESP_021654_0930
# Calculating obsid ESP_022379_0930
# Calculating obsid ESP_020731_0930
# Calculating obsid ESP_020533_0930
# Calculating obsid ESP_021483_0930
# Calculating obsid ESP_020229_0930
# Martian year: 29
# Calculating obsid ESP_012648_0930
# Calculating obsid ESP_012081_0930
# Calculating obsid ESP_011422_0930
# Calculating obsid ESP_012648_0930
# Calculating obsid ESP_012081_0930
# Calculating obsid ESP_011422_0930
# Calculating obsid ESP_012648_0930
# Calculating obsid ESP_012081_0930
# Calculating obsid ESP_011422_0930
# Martian year: 30
# Martian year: 29
# Calculating obsid ESP_011680_1055
# Calculating obsid ESP_011680_1055
# Calculating obsid ESP_011680_1055
# Martian year: 30
# Martian year: 29
# Calculating obsid ESP_012393_0965
# Calculating obsid ESP_012604_0965
# Calculating obsid ESP_012248_0965
# Calculating obsid ESP_012314_0965
# Calculating obsid ESP_012393_0965
# Calculating obsid ESP_012604_0965
# Calculating obsid ESP_012248_0965
# Calculating obsid ESP_012314_0965
# Calculating obsid ESP_012393_0965
# Calculating obsid ESP_012604_0965
# Calculating obsid ESP_012248_0965
# Calculating obsid ESP_012314_0965
# Martian year: 30
# Martian year: 29
# Calculating obsid ESP_012821_0865
# Calculating obsid ESP_012821_0865
# Calculating obsid ESP_012821_0865
# Martian year: 30
# Calculating obsid ESP_020532_0935
# Calculating obsid ESP_021468_0935
# Calculating obsid ESP_020255_0935
# Calculating obsid ESP_022339_0935
# Calculating obsid ESP_020888_0935
# Calculating obsid ESP_020532_0935
# Calculating obsid ESP_021468_0935
# Calculating obsid ESP_020255_0935
# Calculating obsid ESP_022339_0935
# Calculating obsid ESP_020888_0935
# Calculating obsid ESP_020532_0935
# Calculating obsid ESP_021468_0935
# Calculating obsid ESP_020255_0935
# Calculating obsid ESP_022339_0935
# Calculating obsid ESP_020888_0935
# Martian year: 29
# Calculating obsid ESP_011921_0950
# Calculating obsid ESP_011921_0950
# Calculating obsid ESP_011921_0950
# Martian year: 30
# Martian year: 29
# Calculating obsid ESP_012254_1065
# Calculating obsid ESP_012887_1065
# Calculating obsid ESP_012254_1065
# Calculating obsid ESP_012887_1065
# Calculating obsid ESP_012254_1065
# Calculating obsid ESP_012887_1065
# Martian year: 30
# Martian year: 29
# Calculating obsid ESP_012038_0930
# Calculating obsid ESP_012671_0930
# Calculating obsid ESP_012816_0930
# Calculating obsid ESP_012038_0930
# Calculating obsid ESP_012671_0930
# Calculating obsid ESP_012816_0930
# Calculating obsid ESP_012038_0930
# Calculating obsid ESP_012671_0930
# Calculating obsid ESP_012816_0930
# Martian year: 30
# Martian year: 29
# Calculating obsid ESP_011413_0970
# Calculating obsid ESP_011413_0970
# Calculating obsid ESP_011413_0970
# Martian year: 30
# Martian year: 29
# Martian year: 30
# Calculating obsid ESP_022193_0950
# Calculating obsid ESP_022193_0950
# Calculating obsid ESP_022193_0950

# %%
calc_region
# Out:
# [    Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0   -85.4074  214.785  29      both     0.115        933  ESP_012079_0945
#  1   -85.4065  183.727  29      both     0.070       1971  ESP_011407_0945
#  2   -85.4056  198.040  29      both     0.072       1525  ESP_011723_0945
#  3   -85.4049  207.892  29      both     0.168        788  ESP_011934_0945
#  4   -85.4067  235.282  29      both     0.111       1285  ESP_012501_0945
#  5   -85.4117  224.964  29      both     0.087        350  ESP_012290_0945
#  6   -85.4086  183.683  29      both     0.074        453  ESP_011406_0945
#  7   -85.4074  214.785  29      fans     0.088        781  ESP_012079_0945
#  8   -85.4065  183.727  29      fans     0.046       1568  ESP_011407_0945
#  9   -85.4056  198.040  29      fans     0.047        939  ESP_011723_0945
#  10  -85.4049  207.892  29      fans     0.126        678  ESP_011934_0945
#  11  -85.4067  235.282  29      fans     0.097       1253  ESP_012501_0945
#  12  -85.4117  224.964  29      fans     0.083        326  ESP_012290_0945
#  13  -85.4086  183.683  29      fans     0.026        291  ESP_011406_0945
#  14  -85.4074  214.785  29  blotches     0.037        331  ESP_012079_0945
#  15  -85.4065  183.727  29  blotches     0.029        529  ESP_011407_0945
#  16  -85.4056  198.040  29  blotches     0.032        808  ESP_011723_0945
#  17  -85.4049  207.892  29  blotches     0.057        230  ESP_011934_0945
#  18  -85.4067  235.282  29  blotches     0.021        131  ESP_012501_0945
#  19  -85.4117  224.964  29  blotches     0.006         47  ESP_012290_0945
#  20  -85.4086  183.683  29  blotches     0.056        256  ESP_011406_0945
#  21  -85.4041  243.978  30      both     0.049       2256  ESP_021494_0945
,
#      Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0   -81.8089  196.842  29      both     0.041       1250  ESP_011697_0980
#  1   -81.7969  180.809  29      both     0.102        475  ESP_011341_0980
#  2   -81.8017  203.570  29      both     0.163        886  ESP_011842_0980
#  3   -81.8115  187.254  29      both     0.077        525  ESP_011486_0980
#  4   -81.8116  240.503  29      both     0.024        728  ESP_012607_0980
#  5   -81.8074  213.543  29      both     0.006        101  ESP_012053_0980
#  6   -81.8105  223.702  29      both     0.002         34  ESP_012264_0980
#  7   -81.8089  196.842  29      fans     0.022        755  ESP_011697_0980
#  8   -81.7969  180.809  29      fans     0.062        322  ESP_011341_0980
#  9   -81.8017  203.570  29      fans     0.081        563  ESP_011842_0980
#  10  -81.8115  187.254  29      fans     0.029        181  ESP_011486_0980
#  11  -81.8116  240.503  29      fans     0.003         65  ESP_012607_0980
#  12  -81.8074  213.543  29      fans     0.003         27  ESP_012053_0980
#  13  -81.8105  223.702  29      fans     0.000          1  ESP_012264_0980
#  14  -81.8089  196.842  29  blotches     0.022        645  ESP_011697_0980
#  15  -81.7969  180.809  29  blotches     0.047        219  ESP_011341_0980
#  16  -81.8017  203.570  29  blotches     0.100        518  ESP_011842_0980
#  17  -81.8115  187.254  29  blotches     0.050        400  ESP_011486_0980
#  18  -81.8116  240.503  29  blotches     0.021        695  ESP_012607_0980
#  19  -81.8074  213.543  29  blotches     0.003         75  ESP_012053_0980
#  20  -81.8105  223.702  29  blotches     0.002         33  ESP_012264_0980
#  21  -81.8120  204.439  30      both     0.089        343  ESP_020677_0980
#  22  -81.8075  208.155  30      both     0.024        134  ESP_020756_0980
#  23  -81.8403  267.433  30      both     0.005         50  ESP_021969_0980
#  24  -81.8120  204.439  30      fans     0.057        229  ESP_020677_0980
#  25  -81.8075  208.155  30      fans     0.015         51  ESP_020756_0980
#  26  -81.8403  267.433  30      fans     0.000          1  ESP_021969_0980
#  27  -81.8120  204.439  30  blotches     0.037        164  ESP_020677_0980
#  28  -81.8075  208.155  30  blotches     0.009         87  ESP_020756_0980
#  29  -81.8403  267.433  30  blotches     0.005         49  ESP_021969_0980
#
#        pixel_area region_name
#  0   2.994071e+06   Starburst
#  1   5.214409e+06   Starburst
#  2   1.081647e+07   Starburst
#  3   6.782615e+06   Starburst
#  4   1.209718e+06   Starburst
#  5   1.197784e+06   Starburst
#  6   3.942761e+05   Starburst
#  7   1.621656e+06   Starburst
#  8   3.161151e+06   Starburst
#  9   5.372278e+06   Starburst
#  10  2.582892e+06   Starburst
#  11  1.535927e+05   Starburst
#  12  5.981652e+05   Starburst
#  13  8.328679e+03   Starburst
#  14  1.645233e+06   Starburst
#  15  2.416194e+06   Starburst
#  16  6.639572e+06   Starburst
#  17  4.456337e+06   Starburst
#  18  1.090591e+06   Starburst
#  19  6.079568e+05   Starburst
#  20  3.859474e+05   Starburst
#  21  9.694928e+06   Starburst
#  22  2.625282e+06   Starburst
#  23  2.595728e+05   Starburst
#  24  6.251620e+06   Starburst
#  25  1.668671e+06   Starburst
#  26  3.503398e+03   Starburst
#  27  4.067113e+06   Starburst
#  28  9.623304e+05   Starburst
#  29  2.560694e+05   Starburst  ,
#      Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0   
#  44  -86.3812  244.027  30  blotches     0.038       1626  ESP_021495_0935
#  45  -86.4100  217.590  30  blotches     0.009         33  ESP_020954_0935
#  46  -86.3940  200.753  30  blotches     0.060        176  ESP_020598_0935
#  47  -86.4047  183.313  30  blotches     0.034        230  ESP_020214_0935
#  48  -86.3956  281.619  30  blotches     0.001         34  ESP_022260_0935
#  49  -86.3953  188.091  30  blotches     0.134        234  ESP_020321_0935
#  50  -86.3737  182.781  30  blotches     0.043        256  ESP_020202_0935
#
#        pixel_area        region_name
#  0   3.588417e+06  Manhattan_Classic
#  1   3.116132e+06  Manhattan_Classic
#  2   2.215955e+06  Manhattan_Classic
#  3   4.555197e+06  Manhattan_Classic
#  4   4.689980e+06  Manhattan_Classic
#  5   2.504136e+06  Manhattan_Classic
#  6   1.507968e+06  Manhattan_Classic
#  7   7.603556e+05  Manhattan_Classic
#  8   1.837569e+06  Manhattan_Classic
#  9   2.758434e+06  Manhattan_Classic
#  10  1.278916e+06  Manhattan_Classic
#  11  3.660505e+06  Manhattan_Classic
#  12  2.740194e+06  Manhattan_Classic
#  13  1.548590e+06  Manhattan_Classic
#  14  3.639324e+05  Manhattan_Classic
#  15  6.538624e+05  Manhattan_Classic
#  16  2.059682e+06  Manhattan_Classic
#  17  4.026352e+05  Manhattan_Classic
#  18  1.127226e+06  Manhattan_Classic
#  19  1.142715e+06  Manhattan_Classic
#  20  2.268924e+06  Manhattan_Classic
#  21  1.177323e+06  Manhattan_Classic
#  22  1.218654e+06  Manhattan_Classic
#  23  1.337646e+05  Manhattan_Classic
#  24  8.839574e+06  Manhattan_Classic
#  25  6.066213e+06  Manhattan_Classic
#  26  1.387499e+07  Manhattan_Classic
#  27  5.792790e+06  Manhattan_Classic
#  28  5.483670e+06  Manhattan_Classic
#  29  2.286085e+06  Manhattan_Classic
#  30  1.870377e+05  Manhattan_Classic
#  31  7.146483e+06  Manhattan_Classic
#  32  1.181384e+06  Manhattan_Classic
#  33  5.451019e+06  Manhattan_Classic
#  34  3.129087e+06  Manhattan_Classic
#  35  8.515451e+06  Manhattan_Classic
#  36  4.903959e+06  Manhattan_Classic
#  37  3.428761e+06  Manhattan_Classic
#  38  6.873397e+05  Manhattan_Classic
#  39  1.100281e+05  Manhattan_Classic
#  40  1.780644e+06  Manhattan_Classic
#  41  4.982881e+05  Manhattan_Classic
#  42  4.216161e+06  Manhattan_Classic
#  43  3.520158e+06  Manhattan_Classic
#  44  7.052130e+06  Manhattan_Classic
#  45  1.026015e+06  Manhattan_Classic
#  46  2.627628e+06  Manhattan_Classic
#  47  1.889950e+06  Manhattan_Classic
#  48  8.566168e+04  Manhattan_Classic
#  49  5.890292e+06  Manhattan_Classic
#  50  7.790035e+05  Manhattan_Classic  ,
#     Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0  -82.1867  211.399  29      both     0.100       3579  ESP_012008_0975
#  1  -82.1965  178.833  29      both     0.072       4540  ESP_011296_0975
#  2  -82.1867  211.399  29      fans     0.013        631  ESP_012008_0975
#  3  -82.1965  178.833  29      fans     0.060       3806  ESP_011296_0975
#  4  -82.1867  211.399  29  blotches     0.092       3251  ESP_012008_0975
#  5  -82.1965  178.833  29  blotches     0.013        932  ESP_011296_0975
#
#       pixel_area region_name
#  0  1.465396e+07  Wellington
#  1  2.665742e+06  Wellington
#  2  1.881408e+06  Wellington
#  3  2.231081e+06  Wellington
#  4  1.348054e+07  Wellington
#  5  4.808852e+05  Wellington  ,
#      Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0   
,
#      Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0   -87.0015  197.486  29      both     0.040        261  ESP_011711_0930
#  1   -87.0001  259.432  29      both     0.007         72  ESP_012990_0930
#  2   -87.0034  241.834  29      both     0.008        351  ESP_012634_0930
#  3   -86.9757  204.224  29      both     0.024        139  ESP_011856_0930
#  4   -87.0014  249.000  29      both     0.004        175  ESP_012779_0930
#  5   -87.0015  197.486  29      fans     0.027        174  ESP_011711_0930
#  6   -87.0001  259.432  29      fans     0.002          8  ESP_012990_0930
#  7   -87.0034  241.834  29      fans     0.003        139  ESP_012634_0930
#  8   -86.9757  204.224  29      fans     0.016         83  ESP_011856_0930
#  9   -87.0014  249.000  29      fans     0.001         35  ESP_012779_0930
#  10  -87.0015  197.486  29  blotches     0.015        144  ESP_011711_0930
#  11  -87.0001  259.432  29  blotches     0.005         66  ESP_012990_0930
#  12  -87.0034  241.834  29  blotches     0.005        236  ESP_012634_0930
#  13  -86.9757  204.224  29  blotches     0.009         70  ESP_011856_0930
#  14  -87.0014  249.000  29  blotches     0.003        147  ESP_012779_0930
#  15  -86.9964  181.632  30      both     0.013        112  ESP_020176_0930
#  16  -86.9902  192.887  30      both     0.053        180  ESP_020427_0930
#  17  -86.9894  186.341  30      both     0.018        142  ESP_020282_0930
#  18  -86.9964  181.632  30      fans     0.002         17  ESP_020176_0930
#  19  -86.9902  192.887  30      fans     0.017         50  ESP_020427_0930
#  20  -86.9894  186.341  30      fans     0.006         22  ESP_020282_0930
#  21  -86.9964  181.632  30  blotches     0.011        106  ESP_020176_0930
#  22  -86.9902  192.887  30  blotches     0.044        170  ESP_020427_0930
#  23  -86.9894  186.341  30  blotches     0.014        135  ESP_020282_0930
#
#        pixel_area            region_name
#  0   3.800914e+06  Manhattan_Frontinella
#  1   1.028425e+06  Manhattan_Frontinella
#  2   6.043651e+05  Manhattan_Frontinella
#  3   1.801778e+06  Manhattan_Frontinella
#  4   1.832207e+05  Manhattan_Frontinella
#  5   2.618203e+06  Manhattan_Frontinella
#  6   2.670036e+05  Manhattan_Frontinella
#  7   2.407684e+05  Manhattan_Frontinella
#  8   1.215512e+06  Manhattan_Frontinella
#  9   4.198385e+04  Manhattan_Frontinella
#  10  1.394086e+06  Manhattan_Frontinella
#  11  7.796699e+05  Manhattan_Frontinella
#  12  3.848443e+05  Manhattan_Frontinella
#  13  6.385856e+05  Manhattan_Frontinella
#  14  1.433219e+05  Manhattan_Frontinella
#  15  2.305137e+05  Manhattan_Frontinella
#  16  1.916943e+06  Manhattan_Frontinella
#  17  6.664051e+05  Manhattan_Frontinella
#  18  4.493177e+04  Manhattan_Frontinella
#  19  6.243361e+05  Manhattan_Frontinella
#  20  2.253918e+05  Manhattan_Frontinella
#  21  2.040681e+05  Manhattan_Frontinella
#  22  1.596207e+06  Manhattan_Frontinella
#  23  5.184507e+05  Manhattan_Frontinella  ,
#      Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0   -81.9149  221.909  29      both     0.051       1697  ESP_012227_0980
#  1   -81.9113  253.008  29      both     0.032       1214  ESP_012860_0980
#  2   -81.9080  256.914  29      both     0.039       1387  ESP_012939_0980
#  3   -81.9247  182.088  29      both     0.002         74  ESP_011370_0980
#  4   -81.9080  235.430  29      both     0.041       1362  ESP_012504_0980
#  5   -81.9079  201.238  29      both     0.040        650  ESP_011792_0980
#  6   -81.9134  188.557  29      both     0.009        185  ESP_011515_0980
#  7   -81.9149  221.909  29      fans     0.021        789  ESP_012227_0980
#  43  -81.3798  182.428  30  blotches     0.044        775  ESP_020194_0985
#  44  -81.4043  302.421  30  blotches     0.010        301  ESP_022699_0985
#
#        pixel_area region_name
#  0   4.691213e+06   Inca_City
#  1   1.408709e+06   Inca_City
#  2   6.628725e+06   Inca_City
#  3   1.256449e+06   Inca_City
#  4   3.108856e+06   Inca_City
#  5   2.287183e+06   Inca_City
#  6   1.671466e+06   Inca_City
#  7   1.519306e+06   Inca_City
#  8   1.640967e+06   Inca_City
#  9   3.532529e+05   Inca_City
#  10  6.105840e+05   Inca_City
#  11  1.561820e+05   Inca_City
# ...
#  34  2.583824e+05     Potsdam
#  35  4.088169e+05     Potsdam
#  36  0.000000e+00     Potsdam
#  37  1.529231e+06     Potsdam
#  38  1.862070e+05     Potsdam
#  39  6.144458e+05     Potsdam
#  40  1.150206e+06     Potsdam
#  41  5.158528e+05     Potsdam
#  42  6.658032e+05     Potsdam
#  43  5.727347e+05     Potsdam
#  44  6.559400e+05     Potsdam
#  45  4.550185e+04     Potsdam
#  46  2.232141e+05     Potsdam
#  47  4.599893e+05     Potsdam  ,
#      Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0   -85.0360  244.748  29      both     0.017       1295  ESP_012693_0950
#  1   -85.0360  251.919  29      both     0.012        738  ESP_012838_0950
#  2   -85.0334  262.343  29      both     0.031        835  ESP_013049_0950
#  3   -85.0427  181.117  29      both     0.004        176  ESP_011348_0950
#  4   -85.0346  272.705  29      both     0.030        470  ESP_013260_0950
#  5   -85.0360  244.748  29      fans     0.010        585  ESP_012693_0950
#  6   -85.0360  251.919  29      fans     0.008        371  ESP_012838_0950
#  7   -85.0334  262.343  29      fans     0.017        525  ESP_013049_0950
#  8   -85.0427  181.117  29      fans     0.000          4  ESP_011348_0950
#  9   -85.0346  272.705  29      fans     0.013        185  ESP_013260_0950
#  10  -85.0360  244.748  29  blotches     0.009        886  ESP_012693_0950
#  11  -85.0360  251.919  29  blotches     0.005        490  ESP_012838_0950
#  12  -85.0334  262.343  29  blotches     0.015        402  ESP_013049_0950
#  13  -85.0427  181.117  29  blotches     0.004        173  ESP_011348_0950
#  14  -85.0346  272.705  29  blotches     0.018        313  ESP_013260_0950
#
#        pixel_area region_name
#  0   3.796085e+06        Troy
#  1   1.789712e+06        Troy
#  2   8.926214e+05        Troy
#  3   1.379161e+05        Troy
#  4   4.425654e+06        Troy
#  5   2.103968e+06        Troy
#  6   1.186464e+06        Troy
#  7   4.983884e+05        Troy
#  8   1.643270e+03        Troy
#  9   1.960473e+06        Troy
#  10  1.894807e+06        Troy
#  11  6.634447e+05        Troy
#  12  4.447700e+05        Troy
#  13  1.364431e+05        Troy
#  14  2.587903e+06        Troy  ,
#      Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0   -87.0198  233.415  29      both     0.036       1834  ESP_012463_0930
#  1   -87.0190  261.406  29      both     0.068        608  ESP_013030_0930
#  2   -87.0175  192.676  29      both     0.037        110  ESP_011606_0930
#  3   -87.0190  250.979  29      both     0.041       1592  ESP_012819_0930
#  4   -87.0174  212.350  29      both     0.042         62  ESP_012028_0930
#  5   -87.0192  183.771  29      both     0.013        135  ESP_011408_0930
#  3   1.484883e+06  Oswego_Edge
#  4   1.518323e+06  Oswego_Edge
#  5   3.178878e+05  Oswego_Edge
#  6   1.420282e+06  Oswego_Edge
#  7   2.713898e+06  Oswego_Edge
#  8   8.533600e+05  Oswego_Edge
#  9   3.947536e+05  Oswego_Edge
#  10  1.201894e+06  Oswego_Edge
#  11  1.459156e+04  Oswego_Edge
#  12  7.844685e+05  Oswego_Edge
#  13  2.587917e+06  Oswego_Edge
#  14  8.466921e+05  Oswego_Edge
#  15  1.163206e+06  Oswego_Edge
#  16  3.337735e+05  Oswego_Edge
#  17  3.079783e+05  Oswego_Edge
#  18  2.465800e+06  Oswego_Edge
#  19  3.848073e+06  Oswego_Edge
#  20  3.001700e+06  Oswego_Edge
#  21  1.476755e+06  Oswego_Edge
#  22  5.781383e+06  Oswego_Edge
#  23  1.487787e+05  Oswego_Edge
#  24  1.372849e+06  Oswego_Edge
#  25  2.009348e+06  Oswego_Edge
#  26  9.565327e+05  Oswego_Edge
#  27  1.042200e+06  Oswego_Edge
#  28  1.967057e+05  Oswego_Edge
#  29  1.792463e+06  Oswego_Edge
#  30  2.109891e+06  Oswego_Edge
#  31  1.255794e+06  Oswego_Edge
#  32  1.407361e+06  Oswego_Edge
#  33  0.000000e+00  Oswego_Edge
#  34  9.527411e+05  Oswego_Edge
#  35  8.404025e+05  Oswego_Edge
#  36  6.136115e+05  Oswego_Edge
#  37  2.799328e+04  Oswego_Edge
#  38  2.386386e+06  Oswego_Edge
#  39  2.383359e+06  Oswego_Edge
#  40  9.718613e+05  Oswego_Edge
#  41  2.359831e+05  Oswego_Edge
#  42  4.686169e+06  Oswego_Edge
#  43  1.487787e+05  Oswego_Edge
#  44  4.282294e+05  Oswego_Edge
#  45  1.362174e+06  Oswego_Edge
#  46  4.025878e+05  Oswego_Edge
#  47  1.025173e+06  Oswego_Edge  ,
#     Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0  -87.0438  242.525  29      both     0.012        792  ESP_012648_0930
#  1  -87.0442  214.880  29      both     0.083       1219  ESP_012081_0930
#  2  -87.0408  184.393  29      both     0.002         82  ESP_011422_0930
#  3  -87.0438  242.525  29      fans     0.001         37  ESP_012648_0930
#  4  -87.0442  214.880  29      fans     0.065        969  ESP_012081_0930
#  5  -87.0408  184.393  29      fans     0.000          0  ESP_011422_0930
#  6  -87.0438  242.525  29  blotches     0.011        775  ESP_012648_0930
#  7  -87.0442  214.880  29  blotches     0.021        312  ESP_012081_0930
#  8  -87.0408  184.393  29  blotches     0.002         82  ESP_011422_0930
#
#       pixel_area region_name
#  0  1.118753e+06     Halifax
#  1  2.418075e+06     Halifax
#  2  4.993929e+04     Halifax
#  3  9.368089e+04     Halifax
#  4  1.897298e+06     Halifax
#  5  0.000000e+00     Halifax
#  6  1.030208e+06     Halifax
#  7  6.080746e+05     Halifax
#  8  4.993929e+04     Halifax  ,
#     Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0  -74.2302  196.062  29      both     0.073       8461  ESP_011680_1055
#  1  -74.2302  196.062  29      fans     0.023       3633  ESP_011680_1055
#  2  -74.2302  196.062  29  blotches     0.054       5866  ESP_011680_1055
#
#       pixel_area  region_name
#  0  1.480577e+07  Caterpillar
#  1  4.740408e+06  Caterpillar
#  2  1.101121e+07  Caterpillar  ,
#      Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0   -83.2225  229.987  29      both     0.127       8069  ESP_012393_0965
#  1   -83.2212  240.354  29      both     0.145      16728  ESP_012604_0965
#  2   -83.2224  222.926  29      both     0.151      15605  ESP_012248_0965
#  3   -83.2259  226.132  29      both     0.144      16188  ESP_012314_0965
#  4   -83.2225  229.987  29      fans     0.000          0  ESP_012393_0965
#  5   -83.2212  240.354  29      fans     0.000          7  ESP_012604_0965
#  6   -83.2224  222.926  29      fans     0.000         20  ESP_012248_0965
#  7   -83.2259  226.132  29      fans     0.000         11  ESP_012314_0965
#  8   -83.2225  229.987  29  blotches     0.127       8069  ESP_012393_0965
#  9   -83.2212  240.354  29  blotches     0.145      16728  ESP_012604_0965
#  10  -83.2224  222.926  29  blotches     0.151      15593  ESP_012248_0965
#  11  -83.2259  226.132  29  blotches     0.144      16184  ESP_012314_0965
#
#        pixel_area region_name
#  0   3.699250e+06   Rochester
#  1   8.493196e+06   Rochester
#  2   8.811307e+06   Rochester
#  3   8.409343e+06   Rochester
#  4   0.000000e+00   Rochester
#  5   7.319216e+03   Rochester
#  6   2.479578e+04   Rochester
#  7   1.477577e+04   Rochester
#  8   3.699250e+06   Rochester
#  9   8.490612e+06   Rochester
#  10  8.794742e+06   Rochester
#  11  8.401302e+06   Rochester  ,
#      Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0   -86.2466  251.077  29      both     0.062       2090  ESP_012821_0865
#  1   -86.2466  251.077  29      fans     0.016        357  ESP_012821_0865
#  2   -86.2466  251.077  29  blotches     0.050       1818  ESP_012821_0865
#  3   -86.2599  197.699  30      both     0.077        135  ESP_020532_0935
#  4   -86.2535  242.693  30      both     0.060       4221  ESP_021468_0935
#  5   -86.2587  185.136  30      both     0.068        270  ESP_020255_0935
#  6   -86.2751  285.423  30      both     0.001         28  ESP_022339_0935
#  7   -86.2597  214.426  30      both     0.042         79  ESP_020888_0935
#  8   -86.2599  197.699  30      fans     0.054         54  ESP_020532_0935
#  9   -86.2535  242.693  30      fans     0.036       2234  ESP_021468_0935
#  10  -86.2587  185.136  30      fans     0.018        128  ESP_020255_0935
#  11  -86.2751  285.423  30      fans     0.000          1  ESP_022339_0935
#  12  -86.2597  214.426  30      fans     0.033         53  ESP_020888_0935
#  13  -86.2599  197.699  30  blotches     0.025         97  ESP_020532_0935
#  14  -86.2535  242.693  30  blotches     0.027       2392  ESP_021468_0935
#  15  -86.2587  185.136  30  blotches     0.058        208  ESP_020255_0935
#  16  -86.2751  285.423  30  blotches     0.001         27  ESP_022339_0935
#  17  -86.2597  214.426  30  blotches     0.011         36  ESP_020888_0935
#
#        pixel_area       region_name
#  0   1.798122e+06  Manhattan_Cracks
#  1   4.573724e+05  Manhattan_Cracks
#  2   1.446572e+06  Manhattan_Cracks
#  3   2.239769e+06  Manhattan_Cracks
#  4   7.662139e+06  Manhattan_Cracks
#  5   3.941690e+06  Manhattan_Cracks
#  6   8.247347e+04  Manhattan_Cracks
#  7   4.648095e+06  Manhattan_Cracks
#  8   1.565079e+06  Manhattan_Cracks
#  9   4.629921e+06  Manhattan_Cracks
#  10  1.067442e+06  Manhattan_Cracks
#  11  6.941687e+03  Manhattan_Cracks
#  12  3.583056e+06  Manhattan_Cracks
#  13  7.416608e+05  Manhattan_Cracks
#  14  3.392399e+06  Manhattan_Cracks
#  15  3.382135e+06  Manhattan_Cracks
#  16  7.553178e+04  Manhattan_Cracks
#  17  1.182576e+06  Manhattan_Cracks  ,
#     Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0  -85.0057  207.279  29      both     0.056        216  ESP_011921_0950
#  1  -85.0057  207.279  29      fans     0.055        201  ESP_011921_0950
#  2  -85.0057  207.279  29  blotches     0.002         30  ESP_011921_0950
#
#       pixel_area  region_name
#  0  2.471570e+06  Schenectady
#  1  2.425569e+06  Schenectady
#  2  7.473504e+04  Schenectady  ,
#     Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0  -73.4875  223.218  29      both     0.014       2024  ESP_012254_1065
#  1  -73.4787  254.344  29      both     0.031       2805  ESP_012887_1065
#  2  -73.4875  223.218  29      fans     0.004        399  ESP_012254_1065
#  3  -73.4787  254.344  29      fans     0.002         31  ESP_012887_1065
#  4  -73.4875  223.218  29  blotches     0.011       1740  ESP_012254_1065
#  5  -73.4787  254.344  29  blotches     0.030       2790  ESP_012887_1065
#
#       pixel_area region_name
#  0  2.527010e+06  Binghamton
#  1  4.517494e+06  Binghamton
#  2  6.731300e+05  Binghamton
#  3  2.464215e+05  Binghamton
#  4  1.961312e+06  Binghamton
#  5  4.407022e+06  Binghamton  ,
#     Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0  -86.9844  212.826  29      both     0.019        141  ESP_012038_0930
#  1  -86.9850  243.661  29      both     0.010        363  ESP_012671_0930
#  2  -86.9846  250.830  29      both     0.007        400  ESP_012816_0930
#  3  -86.9844  212.826  29      fans     0.018        100  ESP_012038_0930
#  4  -86.9850  243.661  29      fans     0.001         61  ESP_012671_0930
#  5  -86.9846  250.830  29      fans     0.000         39  ESP_012816_0930
#  6  -86.9844  212.826  29  blotches     0.002         60  ESP_012038_0930
#  7  -86.9850  243.661  29  blotches     0.009        316  ESP_012671_0930
#  8  -86.9846  250.830  29  blotches     0.007        375  ESP_012816_0930
#
#       pixel_area region_name
#  0  2.129373e+06        Atka
#  1  2.157060e+05        Atka
#  2  2.131871e+05        Atka
#  3  1.977340e+06        Atka
#  4  1.676939e+04        Atka
#  5  1.064465e+04        Atka
#  6  2.265835e+05        Atka
#  7  2.008836e+05        Atka
#  8  2.039536e+05        Atka  ,
#     Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0  -82.6986  183.994  29      both     0.020        396  ESP_011413_0970
#  1  -82.6986  183.994  29      fans     0.001         15  ESP_011413_0970
#  2  -82.6986  183.994  29  blotches     0.020        388  ESP_011413_0970
#
#        pixel_area region_name
#  0  890048.728226    Cortland
#  1   27308.554873    Cortland
#  2  874008.310243    Cortland  ,
#     Latitude       Ls  MY     Which  fraction  n_objects            obsid  \
#  0  -85.1719  278.375  30      both     0.005         29  ESP_022193_0950
#  1  -85.1719  278.375  30      fans     0.000          1  ESP_022193_0950
#  2  -85.1719  278.375  30  blotches     0.005         28  ESP_022193_0950
#
#        pixel_area region_name
#  0  111883.719935     Geneseo
#  1     298.192450     Geneseo
#  2  111585.527485     Geneseo  ]

# %%
calc_region[0].head()
# Out:
#    Latitude       Ls  MY Which  fraction  n_objects            obsid  \
# 0  -85.4074  214.785  29  both     0.115        933  ESP_012079_0945
# 1  -85.4065  183.727  29  both     0.070       1971  ESP_011407_0945
# 2  -85.4056  198.040  29  both     0.072       1525  ESP_011723_0945
# 3  -85.4049  207.892  29  both     0.168        788  ESP_011934_0945
# 4  -85.4067  235.282  29  both     0.111       1285  ESP_012501_0945
#
#      pixel_area   region_name
# 0  2.551911e+07  Macclesfield
# 1  2.592302e+06  Macclesfield
# 2  8.455380e+06  Macclesfield
# 3  7.357966e+06  Macclesfield
# 4  4.882627e+06  Macclesfield

# %%
full = pd.concat(calc_region, sort=True)

# %%
# exactly what we want! But this is only for which='both', need with fans and blotches too
full.head()
# Out:
#    Latitude       Ls  MY Which  fraction  n_objects            obsid  \
# 0  -85.4074  214.785  29  both     0.115        933  ESP_012079_0945
# 1  -85.4065  183.727  29  both     0.070       1971  ESP_011407_0945
# 2  -85.4056  198.040  29  both     0.072       1525  ESP_011723_0945
# 3  -85.4049  207.892  29  both     0.168        788  ESP_011934_0945
# 4  -85.4067  235.282  29  both     0.111       1285  ESP_012501_0945
#
#      pixel_area   region_name
# 0  2.551911e+07  Macclesfield
# 1  2.592302e+06  Macclesfield
# 2  8.455380e+06  Macclesfield
# 3  7.357966e+06  Macclesfield
# 4  4.882627e+06  Macclesfield

# %%
full.iloc[0]
# Out:
# Latitude              -85.4074
# Ls                     214.785
# MY                          29
# Which                     both
# fraction                 0.115
# n_objects                  933
# obsid          ESP_012079_0945
# pixel_area         2.55191e+07
# region_name       Macclesfield
# Name: 0, dtype: object

# %%
full.to_csv("n_obj_df.csv", index=False)

# %%
calc_coverage("ithaca", which="blotches")
# Out:
# Martian year: 29
# Calculating obsid ESP_011931_0945
# Calculating obsid ESP_012063_0945
# Calculating obsid ESP_011350_0945
# Calculating obsid ESP_012076_0945
# Calculating obsid ESP_012643_0945
# Calculating obsid ESP_012854_0945
# Calculating obsid ESP_011351_0945
# Calculating obsid ESP_011404_0945
# Calculating obsid ESP_011403_0945
# Calculating obsid ESP_012858_0855
# Martian year: 30
# Calculating obsid ESP_020357_0950
# Calculating obsid ESP_020476_0950
# Calculating obsid ESP_021491_0950
# Calculating obsid ESP_020779_0950
# Calculating obsid ESP_020146_0950
# Calculating obsid ESP_020568_0950
#          Ls  MY  fraction            obsid region_name
# 0   207.751  29     0.144  ESP_011931_0945      ithaca
# 1   214.020  29     0.154  ESP_012063_0945      ithaca
# 2   181.205  29     0.044  ESP_011350_0945      ithaca
# 3   214.641  29     0.156  ESP_012076_0945      ithaca
# 4   242.279  29     0.163  ESP_012643_0945      ithaca
# 5   252.710  29     0.132  ESP_012854_0945      ithaca
# 6   181.249  29     0.019  ESP_011351_0945      ithaca
# 7   183.594  29     0.016  ESP_011404_0945      ithaca
# 8   183.549  29     0.015  ESP_011403_0945      ithaca
# 9   252.907  29     0.150  ESP_012858_0855      ithaca
# 10  189.713  30     0.011  ESP_020357_0950      ithaca
# 11  195.125  30     0.030  ESP_020476_0950      ithaca
# 12  243.829  30     0.218  ESP_021491_0950      ithaca
# 13  209.241  30     0.173  ESP_020779_0950      ithaca
# 14  180.311  30     0.029  ESP_020146_0950      ithaca
# 15  199.362  30     0.110  ESP_020568_0950      ithaca

# %%
calc_coverage("ithaca", which="fans")
# Out:
# Martian year: 29
# Calculating obsid ESP_011931_0945
# Calculating obsid ESP_012063_0945
# Calculating obsid ESP_011350_0945
# Calculating obsid ESP_012076_0945
# Calculating obsid ESP_012643_0945
# Calculating obsid ESP_012854_0945
# Calculating obsid ESP_011351_0945
# Calculating obsid ESP_011404_0945
# Calculating obsid ESP_011403_0945
# Calculating obsid ESP_012858_0855
# Martian year: 30
# Calculating obsid ESP_020357_0950
# Calculating obsid ESP_020476_0950
# Calculating obsid ESP_021491_0950
# Calculating obsid ESP_020779_0950
# Calculating obsid ESP_020146_0950
# Calculating obsid ESP_020568_0950
#          Ls  MY  fraction            obsid region_name
# 0   207.751  29     0.134  ESP_011931_0945      ithaca
# 1   214.020  29     0.113  ESP_012063_0945      ithaca
# 2   181.205  29     0.060  ESP_011350_0945      ithaca
# 3   214.641  29     0.109  ESP_012076_0945      ithaca
# 4   242.279  29     0.101  ESP_012643_0945      ithaca
# 5   252.710  29     0.141  ESP_012854_0945      ithaca
# 6   181.249  29     0.040  ESP_011351_0945      ithaca
# 7   183.594  29     0.105  ESP_011404_0945      ithaca
# 8   183.549  29     0.080  ESP_011403_0945      ithaca
# 9   252.907  29     0.119  ESP_012858_0855      ithaca
# 10  189.713  30     0.079  ESP_020357_0950      ithaca
# 11  195.125  30     0.236  ESP_020476_0950      ithaca
# 12  243.829  30     0.168  ESP_021491_0950      ithaca
# 13  209.241  30     0.221  ESP_020779_0950      ithaca
# 14  180.311  30     0.094  ESP_020146_0950      ithaca
# 15  199.362  30     0.297  ESP_020568_0950      ithaca

# %%
calc_coverage("ithaca")
# Out:
# Martian year: 29
# Calculating obsid ESP_011931_0945
# Calculating obsid ESP_012063_0945
# Calculating obsid ESP_011350_0945
# Calculating obsid ESP_012076_0945
# Calculating obsid ESP_012643_0945
# Calculating obsid ESP_012854_0945
# Calculating obsid ESP_011351_0945
# Calculating obsid ESP_011404_0945
# Calculating obsid ESP_011403_0945
# Calculating obsid ESP_012858_0855
# Martian year: 30
# Calculating obsid ESP_020357_0950
# Calculating obsid ESP_020476_0950
# Calculating obsid ESP_021491_0950
# Calculating obsid ESP_020779_0950
# Calculating obsid ESP_020146_0950
# Calculating obsid ESP_020568_0950
#          Ls  MY  fraction            obsid region_name
# 0   207.751  29     0.225  ESP_011931_0945      ithaca
# 1   214.020  29     0.212  ESP_012063_0945      ithaca
# 2   181.205  29     0.091  ESP_011350_0945      ithaca
# 3   214.641  29     0.210  ESP_012076_0945      ithaca
# 4   242.279  29     0.212  ESP_012643_0945      ithaca
# 5   252.710  29     0.229  ESP_012854_0945      ithaca
# 6   181.249  29     0.056  ESP_011351_0945      ithaca
# 7   183.594  29     0.116  ESP_011404_0945      ithaca
# 8   183.549  29     0.088  ESP_011403_0945      ithaca
# 9   252.907  29     0.225  ESP_012858_0855      ithaca
# 10  189.713  30     0.088  ESP_020357_0950      ithaca
# 11  195.125  30     0.248  ESP_020476_0950      ithaca
# 12  243.829  30     0.316  ESP_021491_0950      ithaca
# 13  209.241  30     0.324  ESP_020779_0950      ithaca
# 14  180.311  30     0.119  ESP_020146_0950      ithaca
# 15  199.362  30     0.355  ESP_020568_0950      ithaca

# %%
cc.which
# Out:
# 'both'

# %%
cc.obsid = "ESP_012079_0945"

# %%
cc.covered_fraction
# Out:
# 0.115

# %%
cc.which = "fans"

# %%
cc.covered_fraction
# Out:
# 0.088

# %%
cc.which = "blotches"

# %%
cc.covered_fraction
# Out:
# 0.037

# %% [markdown]
# There's also the union itself and it's area, in case you need it:

# %%
cc.union.area
# Out:
# 8091883.081637692

# %% [markdown]
# And the Ls value for the current obsid:

# %%
cc.Ls
# Out:
# 214.785

# %% [markdown]
# # Region of Interest names
#
# I added also a function to give you the list of obsids for a region name.

# %%
obsids = get_obsids_for_region("ithaca")
obsids
# Out:
# 124    ESP_011931_0945
# 125    ESP_012063_0945
# 126    ESP_020357_0950
# 127    ESP_011350_0945
# 128    ESP_020476_0950
# 129    ESP_021491_0950
# 130    ESP_020779_0950
# 131    ESP_012076_0945
# 132    ESP_012643_0945
# 133    ESP_020146_0950
# 134    ESP_012854_0945
# 135    ESP_011351_0945
# 136    ESP_011404_0945
# 137    ESP_011403_0945
# 138    ESP_020568_0950
# 139    ESP_012858_0855
# 140    PSP_003822_0945
# 141    PSP_002675_0945
# 142    PSP_003466_0945
# 143    PSP_004033_0945
# 144    PSP_003309_0945
# 145    PSP_003453_0945
# 146    PSP_003308_0945
# 147    PSP_003677_0945
# 148    PSP_003310_0855
# 149    PSP_003176_0945
# 150    PSP_003796_0950
# 151    PSP_002622_0945
# 152    PSP_003730_0945
# 153    PSP_003193_0850
# 154    PSP_003756_0945
# 155    PSP_003954_0945
# 156    PSP_004178_0945
# 157    PSP_004891_0945
# 158    PSP_004666_0945
# 159    ESP_029548_0945
# 160    ESP_038040_0950
# 161    ESP_038462_0950
# 162    ESP_037842_0950
# 163    ESP_039359_0950
# 164    ESP_040216_0950
# 165    ESP_040189_0950
# Name: obsid, dtype: object

# %% [markdown]
# ## Restrict to a martian year
#
# by using the MY parameter, you can restrict the obsid list to a specific Martian Year:

# %%
get_obsids_for_region("ithaca", 29)
# Out:
# 124    ESP_011931_0945
# 125    ESP_012063_0945
# 127    ESP_011350_0945
# 131    ESP_012076_0945
# 132    ESP_012643_0945
# 134    ESP_012854_0945
# 135    ESP_011351_0945
# 136    ESP_011404_0945
# 137    ESP_011403_0945
# 139    ESP_012858_0855
# Name: obsid, dtype: object

# %%
get_region_names().roi_name.unique()
# Out:
# array(['Macclesfield', 'unknown', 'Starburst', 'Manhattan_Classic',
#        'Wellington', 'Albany', 'Bilbao', 'Ithaca', 'Portsmouth', 'Pisaq',
#        'Manhattan_Frontinella', 'BuenosAires', 'Inca_City_Ridges',
#        'Inca_City', 'Giza', 'Potsdam', 'Troy', 'Oswego_Edge', 'Halifax',
#        'Caterpillar', 'Rochester', 'Manhattan_Cracks', 'Schenectady',
#        'Binghamton', 'Atka', 'Cortland', 'Geneseo', 'Manhattan2'],
#       dtype=object)

# %%
bucket = []
roi = "ithaca"
for MY in [29, 30]:
    print(f"Martian year: {MY}")
    for obsid in get_obsids_for_region(roi, MY):
        print(f"Calculating obsid {obsid}")
        d = {}
        d["obsid"] = obsid
        d["MY"] = MY
        cc.obsid = obsid
        d["fraction"] = cc.covered_fraction
        d["Ls"] = cc.Ls
        bucket.append(d)
# Out:
# Martian year: 29
# Calculating obsid ESP_011931_0945
# Calculating obsid ESP_012063_0945
# Calculating obsid ESP_011350_0945
# Calculating obsid ESP_012076_0945
# Calculating obsid ESP_012643_0945
# Calculating obsid ESP_012854_0945
# Calculating obsid ESP_011351_0945
# Calculating obsid ESP_011404_0945
# Calculating obsid ESP_011403_0945
# Calculating obsid ESP_012858_0855
# Martian year: 30
# Calculating obsid ESP_020357_0950
# Calculating obsid ESP_020476_0950
# Calculating obsid ESP_021491_0950
# Calculating obsid ESP_020779_0950
# Calculating obsid ESP_020146_0950
# Calculating obsid ESP_020568_0950

# %%
results = pd.DataFrame(bucket)

# %%
results["region_name"] = "given_region"

# %%
results
# Out:
#          Ls  MY  fraction            obsid   region_name
# 0   207.751  29     0.225  ESP_011931_0945  given_region
# 1   214.020  29     0.212  ESP_012063_0945  given_region
# 2   181.205  29     0.091  ESP_011350_0945  given_region
# 3   214.641  29     0.210  ESP_012076_0945  given_region
# 4   242.279  29     0.212  ESP_012643_0945  given_region
# 5   252.710  29     0.229  ESP_012854_0945  given_region
# 6   181.249  29     0.056  ESP_011351_0945  given_region
# 7   183.594  29     0.116  ESP_011404_0945  given_region
# 8   183.549  29     0.088  ESP_011403_0945  given_region
# 9   252.907  29     0.225  ESP_012858_0855  given_region
# 10  189.713  30     0.088  ESP_020357_0950  given_region
# 11  195.125  30     0.248  ESP_020476_0950  given_region
# 12  243.829  30     0.316  ESP_021491_0950  given_region
# 13  209.241  30     0.324  ESP_020779_0950  given_region
# 14  180.311  30     0.119  ESP_020146_0950  given_region
# 15  199.362  30     0.355  ESP_020568_0950  given_region

# %%
import hvplot
import hvplot.pandas
from bokeh.resources import INLINE

# %%
# fix the xticks for better plot comparison
xticks = list(range(170, 301, 10))
xticks
# Out:
# [170, 180, 190, 200, 210, 220, 230, 240, 250, 260, 270, 280, 290, 300]

# %%
savepath = Path(
    "/Users/klay6683/Dropbox/data/planet4/p4_analysis/coverage_plots"
)

# %%
plot = results.hvplot(
    x="Ls",
    y="fraction",
    by="MY",
    kind="scatter",
    title=roi,
    xlim=(170, 300),
    ylim=(-0.05, 0.5),
    grid=True,
    xticks=xticks,
    width=800,
    height=400,
)
# hvplot.show(plot)
for ext in ["png", "html"]:
    hvplot.save(plot, str(savepath / f"{roi}_coverage.{ext}"), resources=INLINE)

# %%
metadata = get_metadata()

# %%
metadata.columns
# Out:
# Index(['OBSERVATION_ID', 'IMAGE_CENTER_LATITUDE', 'IMAGE_CENTER_LONGITUDE',
#        'SOLAR_LONGITUDE', 'START_TIME', 'map_scale', 'north_azimuth',
#        '# of tiles'],
#       dtype='object')

# %% [markdown]
# # Making our Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
# make sure our csv works
p_data = pd.read_csv("final_df.csv")

# %%
p_data.head()
# Out:
#         Ls    MY  fraction            obsid   region_name which
# 0  214.785  29.0     0.115  ESP_012079_0945  Macclesfield  both
# 1  183.727  29.0     0.070  ESP_011407_0945  Macclesfield  both
# 2  198.040  29.0     0.072  ESP_011723_0945  Macclesfield  both
# 3  207.892  29.0     0.168  ESP_011934_0945  Macclesfield  both
# 4  235.282  29.0     0.111  ESP_012501_0945  Macclesfield  both

# %%
grp_both = p_data.groupby("which").get_group("both")

# %%
grp_fans = p_data.groupby("which").get_group("fans")

# %%
grp_blotches = p_data.groupby("which").get_group("blotches")

# %%
grp_both.head()
# Out:
#         Ls    MY  fraction            obsid   region_name which
# 0  214.785  29.0     0.115  ESP_012079_0945  Macclesfield  both
# 1  183.727  29.0     0.070  ESP_011407_0945  Macclesfield  both
# 2  198.040  29.0     0.072  ESP_011723_0945  Macclesfield  both
# 3  207.892  29.0     0.168  ESP_011934_0945  Macclesfield  both
# 4  235.282  29.0     0.111  ESP_012501_0945  Macclesfield  both

# %%
#very nice for saving our plots eg at the end of the plotting write savefig("what_we_call_it.pdf")
from pylab import savefig

# %%
# shows a general view of the fractional coverage of both fans and blotches over time! neato.
# need to remove the fraction label, think its just a line to remove key or legend or whatever, look into tomorrow
grp_both.plot.bar(x="Ls", y="fraction")

# below lines to clean up the graph, comment out to see with every l_s value below (too messy to understand anyways)
ax1 = plt.axes()
x_axis = ax1.axes.get_xaxis()
x_axis.set_visible(False)
plt.ylabel("Fractional Coverage")
# Out:
# C:\Users\Zade Alfalah\AppData\Local\conda\conda\envs\py37\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# Text(0, 0.5, 'Fractional Coverage')

# %%
# group 'both by region'
bbr = grp_both.groupby("region_name")

# %%
# gives the l_s vs fraction graph but by region, need to rewrite so that it displays region name as title.
# done closer below, added titles
# bbr.plot.bar(x="Ls", y="fraction")

# %%
all_regions = get_region_names().roi_name.unique()

# %%
all_regions
# Out:
# array(['Macclesfield', 'unknown', 'Starburst', 'Manhattan_Classic',
#        'Wellington', 'Albany', 'Bilbao', 'Ithaca', 'Portsmouth', 'Pisaq',
#        'Manhattan_Frontinella', 'BuenosAires', 'Inca_City_Ridges',
#        'Inca_City', 'Giza', 'Potsdam', 'Troy', 'Oswego_Edge', 'Halifax',
#        'Caterpillar', 'Rochester', 'Manhattan_Cracks', 'Schenectady',
#        'Binghamton', 'Atka', 'Cortland', 'Geneseo', 'Manhattan2'],
#       dtype=object)

# %%
# remembering how to properly select dataframes
grp_both[grp_both["region_name"] == "Macclesfield"]
# Out:
#          Ls    MY  fraction            obsid   region_name which
# 0   214.785  29.0     0.115  ESP_012079_0945  Macclesfield  both
# 1   183.727  29.0     0.070  ESP_011407_0945  Macclesfield  both
# 2   198.040  29.0     0.072  ESP_011723_0945  Macclesfield  both
# 3   207.892  29.0     0.168  ESP_011934_0945  Macclesfield  both
# 4   235.282  29.0     0.111  ESP_012501_0945  Macclesfield  both
# 5   224.964  29.0     0.087  ESP_012290_0945  Macclesfield  both
# 6   183.683  29.0     0.074  ESP_011406_0945  Macclesfield  both
# 7   243.978  30.0     0.049  ESP_021494_0945  Macclesfield  both
# 8   209.383  30.0     0.075  ESP_020782_0945  Macclesfield  both
# 9   206.269  30.0     0.062  ESP_020716_0945  Macclesfield  both
# 10  199.501  30.0     0.065  ESP_020571_0945  Macclesfield  both
# 11  186.879  30.0     0.080  ESP_020294_0945  Macclesfield  both
# 12  216.293  30.0     0.079  ESP_020927_0945  Macclesfield  both
# 13  184.557  30.0     0.054  ESP_020242_0945  Macclesfield  both

# %%
x = grp_both[grp_both["region_name"] == "Macclesfield"]

# %%
x.plot.bar(x="Ls", y="fraction")
plt.title("Macclesfield")
# Out:
# Text(0.5, 1.0, 'Macclesfield')

# %%
for region_s in all_regions:
    x = grp_both[grp_both["region_name"] == region_s]
    x.plot.bar(x="Ls", y="fraction")
    plt.title(region_s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-285-afdcd4cba81d> in <module>
#       1 for region_s in all_regions:
#       2     x = grp_both[grp_both["region_name"] == region_s]
# ----> 3     x.plot.bar(x="Ls", y="fraction")
#       4     plt.title(region_s)
#
# ~\AppData\Local\conda\conda\envs\py37\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwds)
#    3088             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    3089         """
# -> 3090         return self(kind='bar', x=x, y=y, **kwds)
#    3091
#    3092     def barh(self, x=None, y=None, **kwds):
#
# ~\AppData\Local\conda\conda\envs\py37\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~\AppData\Local\conda\conda\envs\py37\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~\AppData\Local\conda\conda\envs\py37\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# ~\AppData\Local\conda\conda\envs\py37\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     256     def generate(self):
#     257         self._args_adjust()
# --> 258         self._compute_plot_data()
#     259         self._setup_subplots()
#     260         self._make_plot()
#
# ~\AppData\Local\conda\conda\envs\py37\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     371         if is_empty:
#     372             raise TypeError('Empty {0!r}: no numeric data to '
# --> 373                             'plot'.format(numeric_data.__class__.__name__))
#     374
#     375         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot
